# %% [markdown]
# **Python OOPs Questions**

# %% [markdown]
# Answer - 1
#
# Object-Oriented Programming (OOP) is a programming paradigm based on the concept of objects, which are instances of classes. Objects encapsulate data and behavior, making it easier to design and manage complex software systems. OOP emphasizes reusability, modularity, and abstraction.

# %% [markdown]
# Answer - 2
#
# In Object-Oriented Programming (OOP), a class is a blueprint or template used to create objects. It defines the structure and behavior of objects by specifying the attributes (data) and methods (functions) they will have.

# %% [markdown]
# Answer - 3
#
# In Object-Oriented Programming (OOP), an object is an instance of a class. It represents a specific entity that combines data (attributes) and behavior (methods). Objects are used to model real-world entities in a program, encapsulating their properties and actions.

# %% [markdown]
# Answer - 4
#
# Abstraction and encapsulation are two fundamental concepts in Object-Oriented Programming (OOP), but they serve different purposes and focus on distinct aspects of software design. Here’s a detailed comparison:
#
# ![ops.png](data:image/png;base64,...)

# %% [markdown]
# Answer - 5
#
# Dunder methods (short for double underscore methods) in Python are special methods that start and end with double underscores, such as __init__, __str__, and __add__. They are also known as magic methods or special methods and are used to define how objects of a class behave in certain situations, such as when they are printed, compared, or added together.
#
# Dunder methods are not meant to be called directly; instead, they are invoked implicitly by Python in specific contexts.

# %% [markdown]
# Answer - 6
#
# Inheritance in Object-Oriented Programming (OOP) is a mechanism that allows a class (called the child class or subclass) to inherit attributes and methods from another class (called the parent class or superclass). It promotes code reuse, modularity, and the creation of hierarchical relationships between classes.

# %% [markdown]
# Answer - 7
#
# Polymorphism in Object-Oriented Programming (OOP) is the ability of a single interface or method to represent different behaviors in different contexts. It allows objects of different classes to be treated as objects of a common superclass, enabling flexibility and reusability in code.
#
# The term "polymorphism" comes from the Greek words "poly" (many) and "morph" (form), meaning "many forms."

# %% [markdown]
# Answer - 8
#
# Encapsulation is achieved through:
#
# **Private Attributes:** By making attributes private, you prevent direct access from outside the class.
#
#
# **Getter and Setter Methods:** These are used to access and modify private attributes indirectly.
#
#
# **Property Decorators:** These allow controlled access to private attributes without explicitly using getter and setter methods.

# %% [markdown]
# Answer - 9
#
# In Python, a constructor is a special method used to initialize a newly created object. The constructor is automatically called when a new object of a class is created. It is defined using the __init__ method.
#
# The __init__ method allows you to set the initial state of the object by assigning values to its attributes when the object is instantiated.

# %% [markdown]
# Answer - 10
#
# In Python, class methods and static methods are two types of methods that are associated with the class itself rather than with an instance of the class.
#
# **Class Method**
#
# A class method is a method that is bound to the class and not the instance of the class. It takes the class itself as its first argument (usually named cls), rather than the instance (self). This allows the method to access or modify class-level attributes, rather than instance-level attributes.
#
# Class methods are defined using the @classmethod decorator.
#
# **Static Method**
#
# A static method is a method that does not take the instance (self) or the class (cls) as its first argument. It behaves like a regular function that belongs to the class's namespace. Static methods cannot access or modify class or instance attributes. They are defined using the @staticmethod decorator.

# %% [markdown]
# Answer - 11
#
# Method overloading in Python refers to the ability to define multiple methods with the same name but different argument lists (i.e., varying the number or type of arguments). However, unlike some other programming languages like Java or C++, Python does not support true method overloading in the sense of allowing multiple methods with the same name but different signatures.
#
# In Python, if you define a method with the same name more than once, the last definition will overwrite the previous ones. This means that only the most recently defined method will be available, and the previous ones are discarded.

# %% [markdown]
# Answer - 12
#
# Method overriding in Object-Oriented Programming (OOP) occurs when a subclass provides its own implementation of a method that is already defined in its superclass. The method in the subclass has the same name, same parameters, and same return type as the method in the superclass, but it provides a different implementation.

# %% [markdown]
# Answer - 13
#
# The @property decorator in Python is used to define a method as a getter for an attribute. This allows you to access a method like an attribute, without explicitly calling it as a method. The @property decorator makes it possible to define getter, setter, and deleter methods for an attribute, while still maintaining the simplicity of attribute access.

# %% [markdown]
# Answer - 14
#
# Polymorphism is a fundamental concept in Object-Oriented Programming (OOP) that allows objects of different classes to be treated as objects of a common superclass. The key feature of polymorphism is that it enables a single interface to represent different underlying forms (data types or behaviors). In other words, polymorphism allows one function, method, or operator to work in different ways depending on the object it is acting upon

# %% [markdown]
# Answer - 15
#
# An abstract class in Python is a class that cannot be instantiated directly and is meant to be subclassed by other classes. It serves as a blueprint for other classes and can define methods that must be implemented by its subclasses. Abstract classes are used to enforce a common interface for all subclasses, ensuring that they provide specific functionality, but leaving the implementation details to the subclasses.

# %% [markdown]
# Answer - 16
#
# Object-Oriented Programming (OOP) offers several advantages that make it a popular and effective programming paradigm for designing and building complex software systems. Below are the key advantages of OOP:
#
# 1. Modularity
#
# 2. Code Reusability
#
# 3. Abstraction
#
# 4. Encapsulation
#
# 5. Polymorphism

# %% [markdown]
# Answer - 17
#
# In Python, class variables and instance variables are two types of variables used in classes, and they differ in scope, behavior, and how they are shared among objects.
#
# **Class Variable**
#
# A class variable is shared across all instances of a class. It is defined within the class but outside of any instance methods.
#
#
# **Instance Variable**
#
#
# An instance variable is unique to each instance of the class. It is used to store data that is specific to an object.

# %% [markdown]
# Answer - 18
#
# Multiple inheritance in Python is a feature that allows a class to inherit attributes and methods from more than one parent class. This means a child class can derive functionality from multiple base classes, combining their behaviors and properties.

# %% [markdown]
# Answer - 19
#
# In Python, the __str__ and __repr__ methods are special methods used to define string representations for objects. Both serve different purposes:
#
# 1. __repr__:
#
#
# **Purpose:** The __repr__ method is intended to provide a developer-friendly string representation of an object. It should ideally return a string that can recreate the object when passed to eval() (if possible).
#
# 2. __str__:
#
# **Purpose:** The __str__ method is intended to provide a user-friendly or readable string representation of an object. It is typically used when you print an object or use str() on it.

# %% [markdown]
# Answer - 20
#
# The super() function in Python is used to call methods from a parent (or superclass) in a class hierarchy. It is particularly significant in object-oriented programming, especially when working with inheritance.
#
# **Significance of super()**
#
# Clean and Readable Code:
#
# Dynamic Resolution
#
# Support for MRO

# %% [markdown]
# Answer - 21
#
# The __del__ method in Python is a special method, also known as a destructor, that is called when an object is about to be destroyed. It allows developers to define cleanup behavior for an object, such as releasing resources, closing files, or performing other necessary actions before the object is garbage collected.

# %% [markdown]
# Answer - 22
#
#
# In Python, @staticmethod and @classmethod are decorators used to define methods within a class that have different purposes and behaviors. Here's a detailed comparison:
#
# ![sta.png](data:image/png;base64,...)

# %% [markdown]
# Answer - 23
#
# Polymorphism in Python allows objects of different classes to be treated as objects of a common superclass. It enables the same operation or method to behave differently depending on the context or the type of object it is applied to. Polymorphism is a core concept in object-oriented programming and is commonly implemented using inheritance.

# %% [markdown]
# Answer- 24
#
# Method chaining in Python is a programming technique where multiple methods are called on the same object in a single statement. This is made possible by having methods return the object itself (self) after performing their operation. It is commonly used in object-oriented programming (OOP) to create clean, readable, and fluent interfaces.

# %% [markdown]
# Answer - 25
#
# The __call__ method in Python is a special or "magic" method that allows an instance of a class to be called as if it were a function. When you define a __call__ method in a class, you can use objects of that class as callable objects.
#
# **Purpose of __call__**
#
# Callable Objects
#
# Encapsulation
#
# Flexibility
#
# Functional Programming

# %% [markdown]
# **Practical Questions**

# %%
#answer 1

# Parent class
class Animal:
    def speak(self):
        print("This animal makes a sound.")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Create instances
animal = Animal()
dog = Dog()

# Call the speak method on both instances
animal.speak()  # Output: This animal makes a sound.
dog.speak()     # Output: Bark!
# Out:
# This animal makes a sound.
# Bark!

# %%
#answer 2

from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Derived class for Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Derived class for Rectangle
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Example usage
if __name__ == "__main__":
    circle = Circle(5)  # Circle with radius 5
    rectangle = Rectangle(4, 6)  # Rectangle with width 4 and height 6

    print(f"Area of the circle: {circle.area():.2f}")
    print(f"Area of the rectangle: {rectangle.area()}")
# Out:
# Area of the circle: 78.54
# Area of the rectangle: 24

# %%
#answer 3

# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def display_type(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# Derived class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def display_info(self):
        print(f"Car Brand: {self.brand}")

# Further derived class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def display_battery_info(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Example usage
if __name__ == "__main__":
    # Create an ElectricCar object
    tesla = ElectricCar("Electric Vehicle", "Tesla", 100)

    # Display information
    tesla.display_type()            # From Vehicle
    tesla.display_info()            # From Car
    tesla.display_battery_info()    # From ElectricCar
# Out:
# Vehicle Type: Electric Vehicle
# Car Brand: Tesla
# Battery Capacity: 100 kWh

# %%
#answer 4

# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def display_type(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# Derived class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand, model):
        super().__init__(vehicle_type)
        self.brand = brand
        self.model = model

    def display_car_info(self):
        print(f"Car Brand: {self.brand}, Model: {self.model}")

# Further derived class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, model, battery_capacity):
        super().__init__(vehicle_type, brand, model)
        self.battery_capacity = battery_capacity

    def display_battery_info(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Example usage
if __name__ == "__main__":
    # Create an ElectricCar object
    tesla_model_s = ElectricCar("Electric Vehicle", "Tesla", "Model S", 100)

    # Display information
    tesla_model_s.display_type()          # From Vehicle
    tesla_model_s.display_car_info()      # From Car
    tesla_model_s.display_battery_info()  # From ElectricCar
# Out:
# Vehicle Type: Electric Vehicle
# Car Brand: Tesla, Model: Model S
# Battery Capacity: 100 kWh

# %%
#answer 5

class BankAccount:
    def __init__(self, account_holder, initial_balance=0):
        self.__balance = initial_balance  # Private attribute
        self.account_holder = account_holder

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount:.2f}")
        else:
            print("Deposit amount must be positive.")

    # Method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: ${amount:.2f}")
        elif amount > self.__balance:
            print("Insufficient balance.")
        else:
            print("Withdrawal amount must be positive.")

    # Method to check balance
    def check_balance(self):
        print(f"Current Balance: ${self.__balance:.2f}")

# Example usage
if __name__ == "__main__":
    # Create a bank account
    account = BankAccount("John Doe", 1000)

    # Perform transactions
    account.check_balance()  # Check initial balance
    account.deposit(500)     # Deposit money
    account.withdraw(300)    # Withdraw money
    account.withdraw(1500)   # Attempt to withdraw more than balance
    account.check_balance()  # Check final balance
# Out:
# Current Balance: $1000.00
# Deposited: $500.00
# Withdrew: $300.00
# Insufficient balance.
# Current Balance: $1200.00

# %%
#answer 6

# Base class
class Instrument:
    def play(self):
        raise NotImplementedError("Subclass must implement abstract method")

# Derived class for Guitar
class Guitar(Instrument):
    def play(self):
        print("Playing the guitar: Strumming the strings!")

# Derived class for Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano: Pressing the keys!")

# Function to demonstrate polymorphism
def perform(instrument):
    instrument.play()

# Example usage
if __name__ == "__main__":
    # Create instances of Guitar and Piano
    guitar = Guitar()
    piano = Piano()

    # Demonstrate runtime polymorphism
    print("Performance with Guitar:")
    perform(guitar)  # Calls Guitar's play method

    print("\nPerformance with Piano:")
    perform(piano)  # Calls Piano's play method
# Out:
# Performance with Guitar:
# Playing the guitar: Strumming the strings!
#
# Performance with Piano:
# Playing the piano: Pressing the keys!

# %%
#answer 7

class MathOperations:
    @classmethod
    def add_numbers(cls, num1, num2):
        """Class method to add two numbers."""
        return num1 + num2

    @staticmethod
    def subtract_numbers(num1, num2):
        """Static method to subtract two numbers."""
        return num1 - num2

# Example usage
if __name__ == "__main__":
    # Using the class method to add numbers
    result_add = MathOperations.add_numbers(10, 5)
    print(f"Addition Result: {result_add}")

    # Using the static method to subtract numbers
    result_subtract = MathOperations.subtract_numbers(10, 5)
    print(f"Subtraction Result: {result_subtract}")
# Out:
# Addition Result: 15
# Subtraction Result: 5

# %%
#answer 8

class Person:
    # Class attribute to keep track of the count
    count = 0

    def __init__(self, name, age):
        self.name = name
        self.age = age
        # Increment the count when a new instance is created
        Person.count += 1

    @classmethod
    def total_persons(cls):
        """Class method to return the total number of persons created."""
        return cls.count

# Example usage
if __name__ == "__main__":
    # Create instances of Person
    person1 = Person("Alice", 25)
    person2 = Person("Bob", 30)
    person3 = Person("Charlie", 22)

    # Get the total number of persons created
    print(f"Total persons created: {Person.total_persons()}")
# Out:
# Total persons created: 3

# %%
#answer 9

class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero.")
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        """Override the str method to display the fraction."""
        return f"{self.numerator}/{self.denominator}"

# Example usage
if __name__ == "__main__":
    # Create a Fraction object
    fraction1 = Fraction(3, 4)
    fraction2 = Fraction(5, 8)

    # Print the fractions
    print(f"Fraction 1: {fraction1}")
    print(f"Fraction 2: {fraction2}")
# Out:
# Fraction 1: 3/4
# Fraction 2: 5/8

# %%
#answer 10

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        """Override the + operator to add two vectors."""
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        raise TypeError("Operand must be of type Vector")

    def __str__(self):
        """String representation of the vector."""
        return f"Vector({self.x}, {self.y})"

# Example usage
if __name__ == "__main__":
    # Create two Vector objects
    vector1 = Vector(2, 3)
    vector2 = Vector(4, 5)

    # Add the two vectors using the + operator
    result = vector1 + vector2

    # Display the result
    print(f"Vector 1: {vector1}")
    print(f"Vector 2: {vector2}")
    print(f"Result of addition: {result}")
# Out:
# Vector 1: Vector(2, 3)
# Vector 2: Vector(4, 5)
# Result of addition: Vector(6, 8)

# %%
#answer 11

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        """Print a greeting message with the person's name and age."""
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example usage
if __name__ == "__main__":
    # Create a Person object
    person = Person("Alice", 30)

    # Call the greet method
    person.greet()
# Out:
# Hello, my name is Alice and I am 30 years old.

# %%
#answer 12

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        """Compute and return the average of the grades."""
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

# Example usage
if __name__ == "__main__":
    # Create a Student object
    student = Student("John Doe", [85, 90, 78, 92, 88])

    # Calculate and print the average grade
    print(f"Average grade for {student.name}: {student.average_grade():.2f}")
# Out:
# Average grade for John Doe: 86.60

# %%
#answer 13

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        """Set the dimensions of the rectangle."""
        self.length = length
        self.width = width

    def area(self):
        """Calculate and return the area of the rectangle."""
        return self.length * self.width

# Example usage
if __name__ == "__main__":
    # Create a Rectangle object
    rectangle = Rectangle()

    # Set the dimensions of the rectangle
    rectangle.set_dimensions(5, 3)

    # Calculate and print the area
    print(f"Area of the rectangle: {rectangle.area()} square units")
# Out:
# Area of the rectangle: 15 square units

# %%
#answer 14

# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        """Calculate the salary based on hours worked and hourly rate."""
        return self.hours_worked * self.hourly_rate

# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        """Calculate the salary with a bonus for the manager."""
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# Example usage
if __name__ == "__main__":
    # Create an Employee object
    employee = Employee("John Doe", 160, 20)

    # Create a Manager object
    manager = Manager("Alice Smith", 160, 30, 500)

    # Calculate and print the salary for the employee and manager
    print(f"{employee.name}'s Salary: ${employee.calculate_salary()}")
    print(f"{manager.name}'s Salary (with bonus): ${manager.calculate_salary()}")
# Out:
# John Doe's Salary: $3200
# Alice Smith's Salary (with bonus): $5300

# %%
#answer 15

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        """Calculate and return the total price of the product."""
        return self.price * self.quantity

# Example usage
if __name__ == "__main__":
    # Create a Product object
    product = Product("Laptop", 1000, 3)

    # Calculate and print the total price
    print(f"Total price of {product.name}: ${product.total_price()}")
# Out:
# Total price of Laptop: $3000

# %%
#answer 16

from abc import ABC, abstractmethod

# Base class with abstract method
class Animal(ABC):
    @abstractmethod
    def sound(self):
        """Abstract method to be implemented by derived classes."""
        pass

# Derived class Cow
class Cow(Animal):
    def sound(self):
        """Implement the sound for Cow."""
        return "Moo"

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        """Implement the sound for Sheep."""
        return "Baa"

# Example usage
if __name__ == "__main__":
    # Create instances of Cow and Sheep
    cow = Cow()
    sheep = Sheep()

    # Call the sound method for both
    print(f"Cow sound: {cow.sound()}")
    print(f"Sheep sound: {sheep.sound()}")
# Out:
# Cow sound: Moo
# Sheep sound: Baa

# %%
#answer 17

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        """Return a formatted string with the book's details."""
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# Example usage
if __name__ == "__main__":
    # Create a Book object
    book = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)

    # Get and print the book's information
    print(book.get_book_info())
# Out:
# Title: The Great Gatsby
# Author: F. Scott Fitzgerald
# Year Published: 1925

# %%
#answer 18

# Base class House
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_details(self):
        """Return the details of the house."""
        return f"Address: {self.address}\nPrice: ${self.price}"

# Derived class Mansion
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_details(self):
        """Return the details of the mansion, including the number of rooms."""
        base_details = super().get_details()
        return f"{base_details}\nNumber of Rooms: {self.number_of_rooms}"

# Example usage
if __name__ == "__main__":
    # Create a House object
    house = House("123 Elm Street", 250000)

    # Create a Mansion object
    mansion = Mansion("456 Oak Avenue", 5000000, 12)

    # Get and print the details of the house and mansion
    print("House Details:")
    print(house.get_details())

    print("\nMansion Details:")
    print(mansion.get_details())
# Out:
# House Details:
# Address: 123 Elm Street
# Price: $250000
#
# Mansion Details:
# Address: 456 Oak Avenue
# Price: $5000000
# Number of Rooms: 12
